# %% [markdown]
# ## Association Rule Learning

# %% [markdown]
# ### Import libraries

# %%
from apyori import apriori

# import numpy as np
import pandas as pd

# %% [markdown]
# ### Load CSV

# %%
dataset = pd.read_csv('titanic.csv')
dataset.head()

rowCount = dataset.shape[0]
colCount = dataset.shape[1]

# %% [markdown]
# ### Add CSV values to list and add column tags

# %%
records = []

for row in range(0,rowCount):
    records.append([str(dataset.values[row,col]) for col in range(0,colCount)])
    
def add_tags(tuple_list=records):
    for row in tuple_list:
        row[0] = "Class={}".format(row[0])
        row[1] = "Sex={}".format(row[1])
        row[2] = "Age={}".format(row[2])
        row[3] = "Survived={}".format(row[3])
        
add_tags()

# %% [markdown]
# ### Run apriori algorithm

# %%
associationRules = apriori(records, min_support=0.00045, min_confidence=0.02, min_lift=1.4, max_length=6)
associationRules = list(associationRules)

# %% [markdown]
# ### Display association rules

# %%
def print_rules(aprioriRules):
    for item in aprioriRules:
        for ruleNum in range(0,len(item[2])):
            a = item[2][ruleNum][0]
            b = item[2][ruleNum][1]
            outputString = '''Rule: {} -> {}
Support: {}
Confidence: {}
Lift: {}
======================================\n'''.format(str(list(a)),str(list(b)),str(item[1]),\
                                             str(item[2][ruleNum][2]),str(item[2][ruleNum][3]))
            yield(outputString)

# %% [markdown]
# #### Print association rules

# %%
for result in print_rules(associationRules):
    print(result)
# Out:
# Rule: ['Age=Child'] -> ['Class=2nd']
# Support: 0.010904134484325307
# Confidence: 0.22018348623853212
# Lift: 1.7004345726702075
# ======================================
#
# Rule: ['Class=2nd'] -> ['Age=Child']
# Support: 0.010904134484325307
# Confidence: 0.08421052631578947
# Lift: 1.7004345726702077
# ======================================
#
# Rule: ['Age=Child'] -> ['Class=3rd']
# Support: 0.03589277601090413
# Confidence: 0.7247706422018348
# Lift: 2.2595186734932557
# ======================================
#
# Rule: ['Class=3rd'] -> ['Age=Child']
# Support: 0.03589277601090413
# Confidence: 0.11189801699716714
# Lift: 2.2595186734932557
# ======================================
#
# Rule: ['Age=Child'] -> ['Sex=Female']
# Support: 0.02044525215810995
# Confidence: 0.41284403669724773
# Lift: 1.9333398399375368
# ======================================
#
# Rule: ['Sex=Female'] -> ['Age=Child']
# Support: 0.02044525215810995
# Confidence: 0.09574468085106383
# Lift: 1.9333398399375368
# ======================================
#
# Rule: ['Age=Child'] -> ['Survived=Yes']
# Support: 0.025897319400272602
# Confidence: 0.5229357798165137
# Lift: 1.6188208880114583
# ======================================
#
# Rule: ['Survived=Yes'] -> ['Age=Child']
# Support: 0.025897319400272602
# Confidence: 0.08016877637130802
# Lift: 1.6188208880114583
# ======================================
#
# Rule: ['Class=1st'] -> ['Sex=Female']
# Support: 0.06587914584279873
# Confidence: 0.4461538461538462
# Lift: 2.089328968903437
# ======================================
#
# Rule: ['Sex=Female'] -> ['Class=1st']
# Support: 0.06587914584279873
# Confidence: 0.3085106382978724
# Lift: 2.089328968903437
# ======================================
#
# Rule: ['Class=1st'] -> ['Survived=Yes']
# Support: 0.09223080417991822
# Confidence: 0.6246153846153846
# Lift: 1.933584334090663
# ======================================
#
# Rule: ['Survived=Yes'] -> ['Class=1st']
# Support: 0.09223080417991822
# Confidence: 0.28551336146272854
# Lift: 1.933584334090663
# ======================================
#
# Rule: ['Class=2nd'] -> ['Sex=Female']
# Support: 0.0481599273057701
# Confidence: 0.37192982456140344
# Lift: 1.7417394550205298
# ======================================
#
# Rule: ['Sex=Female'] -> ['Class=2nd']
# Support: 0.0481599273057701
# Confidence: 0.225531914893617
# Lift: 1.7417394550205298
# ======================================
#
# Rule: ['Class=2nd'] -> ['Survived=Yes']
# Support: 0.05361199454793276
# Confidence: 0.4140350877192982
# Lift: 1.281703555654255
# ======================================
#
# Rule: ['Survived=Yes'] -> ['Class=2nd']
# Support: 0.05361199454793276
# Confidence: 0.16596343178621661
# Lift: 1.281703555654255
# ======================================
#
# Rule: ['Class=3rd'] -> ['Sex=Female']
# Support: 0.08905043162199
# Confidence: 0.2776203966005666
# Lift: 1.3000904104635045
# ======================================
#
# Rule: ['Sex=Female'] -> ['Class=3rd']
# Support: 0.08905043162199
# Confidence: 0.41702127659574467
# Lift: 1.3000904104635043
# ======================================
#
# Rule: ['Class=3rd'] -> ['Survived=No']
# Support: 0.23989095865515675
# Confidence: 0.7478753541076488
# Lift: 1.104747419054319
# ======================================
#
# Rule: ['Survived=No'] -> ['Class=3rd']
# Support: 0.23989095865515675
# Confidence: 0.35436241610738256
# Lift: 1.1047474190543187
# ======================================
#
# Rule: ['Class=Crew'] -> ['Sex=Male']
# Support: 0.39164016356201725
# Confidence: 0.9740112994350282
# Lift: 1.2384742172481207
# ======================================
#
# Rule: ['Sex=Male'] -> ['Class=Crew']
# Support: 0.39164016356201725
# Confidence: 0.49797804737146156
# Lift: 1.2384742172481207
# ======================================
#
# Rule: ['Class=Crew'] -> ['Survived=No']
# Support: 0.3057701044979555
# Confidence: 0.76045197740113
# Lift: 1.1233253706442197
# ======================================
#
# Rule: ['Survived=No'] -> ['Class=Crew']
# Support: 0.3057701044979555
# Confidence: 0.4516778523489933
# Lift: 1.1233253706442194
# ======================================
#
# Rule: ['Sex=Female'] -> ['Survived=Yes']
# Support: 0.1562925942753294
# Confidence: 0.7319148936170213
# Lift: 2.2657449800999494
# ======================================
#
# Rule: ['Survived=Yes'] -> ['Sex=Female']
# Support: 0.1562925942753294
# Confidence: 0.48382559774964845
# Lift: 2.2657449800999494
# ======================================
#
# Rule: ['Sex=Male'] -> ['Survived=No']
# Support: 0.6197183098591549
# Confidence: 0.7879838243789716
# Lift: 1.163994897622897
# ======================================
#
# Rule: ['Survived=No'] -> ['Sex=Male']
# Support: 0.6197183098591549
# Confidence: 0.9154362416107382
# Lift: 1.163994897622897
# ======================================
#
# Rule: ['Class=1st', 'Age=Adult'] -> ['Sex=Female']
# Support: 0.06542480690595184
# Confidence: 0.4514106583072101
# Lift: 2.1139465083705735
# ======================================
#
# Rule: ['Sex=Female', 'Age=Adult'] -> ['Class=1st']
# Support: 0.06542480690595184
# Confidence: 0.3388235294117647
# Lift: 2.2946171945701357
# ======================================
#
# Rule: ['Class=1st', 'Age=Adult'] -> ['Survived=Yes']
# Support: 0.08950477055883689
# Confidence: 0.6175548589341693
# Lift: 1.9117274887680826
# ======================================
#
# Rule: ['Age=Adult', 'Survived=Yes'] -> ['Class=1st']
# Support: 0.08950477055883689
# Confidence: 0.301223241590214
# Lift: 2.0399764761232646
# ======================================
#
# Rule: ['Class=2nd', 'Age=Adult'] -> ['Sex=Female']
# Support: 0.04225352112676056
# Confidence: 0.3563218390804598
# Lift: 1.668647591098068
# ======================================
#
# Rule: ['Sex=Female', 'Age=Adult'] -> ['Class=2nd']
# Support: 0.04225352112676056
# Confidence: 0.2188235294117647
# Lift: 1.6899318885448913
# ======================================
#
# Rule: ['Class=2nd', 'Age=Adult'] -> ['Survived=Yes']
# Support: 0.04270786006360745
# Confidence: 0.3601532567049809
# Lift: 1.1149048073244205
# ======================================
#
# Rule: ['Age=Adult', 'Survived=Yes'] -> ['Class=2nd']
# Support: 0.04270786006360745
# Confidence: 0.1437308868501529
# Lift: 1.110005901604163
# ======================================
#
# Rule: ['Class=3rd', 'Age=Adult'] -> ['Sex=Female']
# Support: 0.07496592457973648
# Confidence: 0.2631578947368421
# Lift: 1.2323628219484881
# ======================================
#
# Rule: ['Sex=Female', 'Age=Adult'] -> ['Class=3rd']
# Support: 0.07496592457973648
# Confidence: 0.38823529411764707
# Lift: 1.2103482752874521
# ======================================
#
# Rule: ['Class=3rd', 'Age=Adult'] -> ['Survived=No']
# Support: 0.2162653339391186
# Confidence: 0.759170653907496
# Lift: 1.121432623657986
# ======================================
#
# Rule: ['Age=Adult', 'Class=Crew'] -> ['Sex=Male']
# Support: 0.39164016356201725
# Confidence: 0.9740112994350282
# Lift: 1.2384742172481207
# ======================================
#
# Rule: ['Sex=Male', 'Age=Adult'] -> ['Class=Crew']
# Support: 0.39164016356201725
# Confidence: 0.5170965806838632
# Lift: 1.286022117610376
# ======================================
#
# Rule: ['Age=Adult', 'Class=Crew'] -> ['Survived=No']
# Support: 0.3057701044979555
# Confidence: 0.76045197740113
# Lift: 1.1233253706442197
# ======================================
#
# Rule: ['Survived=No', 'Age=Adult'] -> ['Class=Crew']
# Support: 0.3057701044979555
# Confidence: 0.4680111265646732
# Lift: 1.1639463158970007
# ======================================
#
# Rule: ['Sex=Female', 'Age=Adult'] -> ['Survived=Yes']
# Support: 0.14357110404361653
# Confidence: 0.7435294117647059
# Lift: 2.301699346405229
# ======================================
#
# Rule: ['Age=Adult', 'Survived=Yes'] -> ['Sex=Female']
# Support: 0.14357110404361653
# Confidence: 0.4831804281345565
# Lift: 2.2627236645194873
# ======================================
#
# Rule: ['Sex=Male', 'Age=Adult'] -> ['Survived=No']
# Support: 0.6038164470695139
# Confidence: 0.7972405518896222
# Lift: 1.1776687615497037
# ======================================
#
# Rule: ['Survived=No', 'Age=Adult'] -> ['Sex=Male']
# Support: 0.6038164470695139
# Confidence: 0.9242002781641169
# Lift: 1.1751385397106997
# ======================================
#
# Rule: ['Age=Child', 'Class=1st'] -> ['Survived=Yes']
# Support: 0.0027260336210813267
# Confidence: 1.0
# Lift: 3.09563994374121
# ======================================
#
# Rule: ['Age=Child', 'Class=2nd'] -> ['Sex=Female']
# Support: 0.005906406179009541
# Confidence: 0.5416666666666666
# Lift: 2.536613475177305
# ======================================
#
# Rule: ['Age=Child', 'Sex=Female'] -> ['Class=2nd']
# Support: 0.005906406179009541
# Confidence: 0.2888888888888889
# Lift: 2.2310331384015596
# ======================================
#
# Rule: ['Sex=Female', 'Class=2nd'] -> ['Age=Child']
# Support: 0.005906406179009541
# Confidence: 0.12264150943396226
# Lift: 2.47645836939588
# ======================================
#
# Rule: ['Age=Child', 'Sex=Male'] -> ['Class=2nd']
# Support: 0.004997728305315766
# Confidence: 0.171875
# Lift: 1.3273574561403507
# ======================================
#
# Rule: ['Sex=Male', 'Class=2nd'] -> ['Age=Child']
# Support: 0.004997728305315766
# Confidence: 0.06145251396648045
# Lift: 1.240889754497463
# ======================================
#
# Rule: ['Age=Child', 'Class=2nd'] -> ['Survived=Yes']
# Support: 0.010904134484325307
# Confidence: 1.0
# Lift: 3.09563994374121
# ======================================
#
# Rule: ['Age=Child', 'Survived=Yes'] -> ['Class=2nd']
# Support: 0.010904134484325307
# Confidence: 0.4210526315789474
# Lift: 3.251708217913204
# ======================================
#
# Rule: ['Class=2nd', 'Survived=Yes'] -> ['Age=Child']
# Support: 0.010904134484325307
# Confidence: 0.2033898305084746
# Lift: 4.10698180687296
# ======================================
#
# Rule: ['Age=Child', 'Class=3rd'] -> ['Sex=Female']
# Support: 0.014084507042253521
# Confidence: 0.3924050632911393
# Lift: 1.8376245623485055
# ======================================
#
# Rule: ['Age=Child', 'Sex=Female'] -> ['Class=3rd']
# Support: 0.014084507042253521
# Confidence: 0.6888888888888889
# Lift: 2.147655020459553
# ======================================
#
# Rule: ['Class=3rd', 'Sex=Female'] -> ['Age=Child']
# Support: 0.014084507042253521
# Confidence: 0.15816326530612246
# Lift: 3.193737127878675
# ======================================
#
# Rule: ['Age=Child', 'Sex=Male'] -> ['Class=3rd']
# Support: 0.021808268968650613
# Confidence: 0.75
# Lift: 2.338172804532578
# ======================================
#
# Rule: ['Class=3rd', 'Sex=Male'] -> ['Age=Child']
# Support: 0.021808268968650613
# Confidence: 0.09411764705882353
# Lift: 1.9004856988667027
# ======================================
#
# Rule: ['Age=Child', 'Survived=No'] -> ['Class=3rd']
# Support: 0.023625624716038164
# Confidence: 1.0
# Lift: 3.1175637393767706
# ======================================
#
# Rule: ['Class=3rd', 'Survived=No'] -> ['Age=Child']
# Support: 0.023625624716038164
# Confidence: 0.09848484848484848
# Lift: 1.9886711148179037
# ======================================
#
# Rule: ['Age=Child', 'Survived=Yes'] -> ['Class=3rd']
# Support: 0.01226715129486597
# Confidence: 0.4736842105263158
# Lift: 1.4767407186521546
# ======================================
#
# Rule: ['Class=3rd', 'Survived=Yes'] -> ['Age=Child']
# Support: 0.01226715129486597
# Confidence: 0.15168539325842698
# Lift: 3.062931656530255
# ======================================
#
# Rule: ['Age=Child', 'Survived=No'] -> ['Sex=Female']
# Support: 0.007723761926397092
# Confidence: 0.3269230769230769
# Lift: 1.5309738134206219
# ======================================
#
# Rule: ['Survived=No', 'Sex=Female'] -> ['Age=Child']
# Support: 0.007723761926397092
# Confidence: 0.1349206349206349
# Lift: 2.724406582204747
# ======================================
#
# Rule: ['Age=Child', 'Sex=Female'] -> ['Survived=Yes']
# Support: 0.012721490231712857
# Confidence: 0.6222222222222222
# Lift: 1.9261759649945305
# ======================================
#
# Rule: ['Age=Child', 'Survived=Yes'] -> ['Sex=Female']
# Support: 0.012721490231712857
# Confidence: 0.4912280701754386
# Lift: 2.3004106009705114
# ======================================
#
# Rule: ['Sex=Female', 'Survived=Yes'] -> ['Age=Child']
# Support: 0.012721490231712857
# Confidence: 0.0813953488372093
# Lift: 1.643588649455942
# ======================================
#
# Rule: ['Age=Child', 'Sex=Male'] -> ['Survived=Yes']
# Support: 0.013175829168559746
# Confidence: 0.45312500000000006
# Lift: 1.4027118495077358
# ======================================
#
# Rule: ['Sex=Male', 'Survived=Yes'] -> ['Age=Child']
# Support: 0.013175829168559746
# Confidence: 0.07901907356948229
# Lift: 1.5956053296002801
# ======================================
#
# Rule: ['Class=1st', 'Sex=Female'] -> ['Survived=Yes']
# Support: 0.06406179009541117
# Confidence: 0.9724137931034481
# Lift: 3.0102429797759345
# ======================================
#
# Rule: ['Class=1st', 'Survived=Yes'] -> ['Sex=Female']
# Support: 0.06406179009541117
# Confidence: 0.6945812807881773
# Lift: 3.252709359605911
# ======================================
#
# Rule: ['Sex=Female', 'Survived=Yes'] -> ['Class=1st']
# Support: 0.06406179009541117
# Confidence: 0.4098837209302325
# Lift: 2.775858676207513
# ======================================
#
# Rule: ['Survived=No', 'Class=1st'] -> ['Sex=Male']
# Support: 0.05361199454793276
# Confidence: 0.9672131147540983
# Lift: 1.2298301938612193
# ======================================
#
# Rule: ['Sex=Male', 'Survived=Yes'] -> ['Class=1st']
# Support: 0.028169014084507043
# Confidence: 0.16893732970027248
# Lift: 1.144095577447076
# ======================================
#
# Rule: ['Sex=Female', 'Class=2nd'] -> ['Survived=Yes']
# Support: 0.04225352112676056
# Confidence: 0.8773584905660378
# Lift: 2.7159859883767217
# ======================================
#
# Rule: ['Class=2nd', 'Survived=Yes'] -> ['Sex=Female']
# Support: 0.04225352112676056
# Confidence: 0.788135593220339
# Lift: 3.690822214208439
# ======================================
#
# Rule: ['Sex=Female', 'Survived=Yes'] -> ['Class=2nd']
# Support: 0.04225352112676056
# Confidence: 0.2703488372093023
# Lift: 2.087851897184822
# ======================================
#
# Rule: ['Sex=Male', 'Class=2nd'] -> ['Survived=No']
# Support: 0.06996819627442072
# Confidence: 0.8603351955307263
# Lift: 1.270870983465187
# ======================================
#
# Rule: ['Survived=No', 'Class=2nd'] -> ['Sex=Male']
# Support: 0.06996819627442072
# Confidence: 0.9221556886227544
# Lift: 1.1725388045399667
# ======================================
#
# Rule: ['Survived=No', 'Sex=Female'] -> ['Class=3rd']
# Support: 0.0481599273057701
# Confidence: 0.8412698412698413
# Lift: 2.622712352174109
# ======================================
#
# Rule: ['Class=3rd', 'Sex=Female'] -> ['Survived=Yes']
# Support: 0.0408905043162199
# Confidence: 0.45918367346938777
# Lift: 1.4214673211056577
# ======================================
#
# Rule: ['Class=3rd', 'Survived=Yes'] -> ['Sex=Female']
# Support: 0.0408905043162199
# Confidence: 0.5056179775280898
# Lift: 2.3677982309347354
# ======================================
#
# Rule: ['Class=3rd', 'Sex=Male'] -> ['Survived=No']
# Support: 0.19173103134938665
# Confidence: 0.8274509803921569
# Lift: 1.2222950388208977
# ======================================
#
# Rule: ['Sex=Female', 'Class=Crew'] -> ['Survived=Yes']
# Support: 0.009086778736937756
# Confidence: 0.8695652173913044
# Lift: 2.6918608206445307
# ======================================
#
# Rule: ['Sex=Male', 'Class=Crew'] -> ['Survived=No']
# Support: 0.3044070876874148
# Confidence: 0.777262180974478
# Lift: 1.1481570874663263
# ======================================
#
# Rule: ['Survived=No', 'Class=Crew'] -> ['Sex=Male']
# Support: 0.3044070876874148
# Confidence: 0.9955423476968795
# Lift: 1.2658513618029068
# ======================================
#
# Rule: ['Sex=Male', 'Survived=No'] -> ['Class=Crew']
# Support: 0.3044070876874148
# Confidence: 0.4912023460410558
# Lift: 1.2216230097586032
# ======================================
#
# Rule: ['Class=Crew', 'Survived=Yes'] -> ['Sex=Male']
# Support: 0.08723307587460245
# Confidence: 0.9056603773584906
# Lift: 1.1515646970341062
# ======================================
#
# Rule: ['Sex=Male', 'Survived=Yes'] -> ['Class=Crew']
# Support: 0.08723307587460245
# Confidence: 0.5231607629427792
# Lift: 1.301103773149217
# ======================================
#
# Rule: ['Class=1st', 'Sex=Female', 'Age=Adult'] -> ['Survived=Yes']
# Support: 0.06360745115856428
# Confidence: 0.9722222222222221
# Lift: 3.0096499453039534
# ======================================
#
# Rule: ['Class=1st', 'Age=Adult', 'Survived=Yes'] -> ['Sex=Female']
# Support: 0.06360745115856428
# Confidence: 0.7106598984771573
# Lift: 3.3280051841451557
# ======================================
#
# Rule: ['Sex=Female', 'Age=Adult', 'Survived=Yes'] -> ['Class=1st']
# Support: 0.06360745115856428
# Confidence: 0.4430379746835443
# Lift: 3.0003894839337875
# ======================================
#
# Rule: ['Survived=No', 'Class=1st', 'Age=Adult'] -> ['Sex=Male']
# Support: 0.05361199454793276
# Confidence: 0.9672131147540983
# Lift: 1.2298301938612193
# ======================================
#
# Rule: ['Sex=Male', 'Age=Adult', 'Survived=Yes'] -> ['Class=1st']
# Support: 0.025897319400272602
# Confidence: 0.16863905325443787
# Lift: 1.1420755575785162
# ======================================
#
# Rule: ['Class=2nd', 'Age=Adult', 'Sex=Female'] -> ['Survived=Yes']
# Support: 0.03634711494775102
# Confidence: 0.8602150537634409
# Lift: 2.6629160806375998
# ======================================
#
# Rule: ['Class=2nd', 'Age=Adult', 'Survived=Yes'] -> ['Sex=Female']
# Support: 0.03634711494775102
# Confidence: 0.851063829787234
# Lift: 3.9855138071525578
# ======================================
#
# Rule: ['Sex=Female', 'Age=Adult', 'Survived=Yes'] -> ['Class=2nd']
# Support: 0.03634711494775102
# Confidence: 0.25316455696202533
# Lift: 1.9551410170997112
# ======================================
#
# Rule: ['Sex=Male', 'Class=2nd', 'Age=Adult'] -> ['Survived=No']
# Support: 0.06996819627442072
# Confidence: 0.9166666666666667
# Lift: 1.3540827740492172
# ======================================
#
# Rule: ['Survived=No', 'Class=2nd', 'Age=Adult'] -> ['Sex=Male']
# Support: 0.06996819627442072
# Confidence: 0.9221556886227544
# Lift: 1.1725388045399667
# ======================================
#
# Rule: ['Survived=No', 'Sex=Female', 'Age=Adult'] -> ['Class=3rd']
# Support: 0.040436165379373015
# Confidence: 0.81651376146789
# Lift: 2.5455336954544276
# ======================================
#
# Rule: ['Class=3rd', 'Sex=Female', 'Age=Adult'] -> ['Survived=Yes']
# Support: 0.03452975920036347
# Confidence: 0.4606060606060606
# Lift: 1.4258705195414056
# ======================================
#
# Rule: ['Class=3rd', 'Age=Adult', 'Survived=Yes'] -> ['Sex=Female']
# Support: 0.03452975920036347
# Confidence: 0.5033112582781457
# Lift: 2.3569959137663803
# ======================================
#
# Rule: ['Class=3rd', 'Sex=Male', 'Age=Adult'] -> ['Survived=No']
# Support: 0.17582916855974556
# Confidence: 0.8376623376623377
# Lift: 1.237379063889131
# ======================================
#
# Rule: ['Sex=Female', 'Age=Adult', 'Class=Crew'] -> ['Survived=Yes']
# Support: 0.009086778736937756
# Confidence: 0.8695652173913044
# Lift: 2.6918608206445307
# ======================================
#
# Rule: ['Sex=Male', 'Age=Adult', 'Class=Crew'] -> ['Survived=No']
# Support: 0.3044070876874148
# Confidence: 0.777262180974478
# Lift: 1.1481570874663263
# ======================================
#
# Rule: ['Survived=No', 'Age=Adult', 'Class=Crew'] -> ['Sex=Male']
# Support: 0.3044070876874148
# Confidence: 0.9955423476968795
# Lift: 1.2658513618029068
# ======================================
#
# Rule: ['Sex=Male', 'Age=Adult', 'Survived=No'] -> ['Class=Crew']
# Support: 0.3044070876874148
# Confidence: 0.5041384499623777
# Lift: 1.2537951732962636
# ======================================
#
# Rule: ['Age=Adult', 'Survived=Yes', 'Class=Crew'] -> ['Sex=Male']
# Support: 0.08723307587460245
# Confidence: 0.9056603773584906
# Lift: 1.1515646970341062
# ======================================
#
# Rule: ['Sex=Male', 'Age=Adult', 'Survived=Yes'] -> ['Class=Crew']
# Support: 0.08723307587460245
# Confidence: 0.5680473372781065
# Lift: 1.4127369371176413
# ======================================
#
# Rule: ['Age=Child', 'Class=1st', 'Sex=Female'] -> ['Survived=Yes']
# Support: 0.00045433893684688776
# Confidence: 1.0
# Lift: 3.09563994374121
# ======================================
#
# Rule: ['Age=Child', 'Sex=Male', 'Class=1st'] -> ['Survived=Yes']
# Support: 0.002271694684234439
# Confidence: 1.0
# Lift: 3.09563994374121
# ======================================
#
# Rule: ['Age=Child', 'Sex=Male', 'Survived=Yes'] -> ['Class=1st']
# Support: 0.002271694684234439
# Confidence: 0.1724137931034483
# Lift: 1.1676392572944299
# ======================================
#
# Rule: ['Sex=Male', 'Class=1st', 'Survived=Yes'] -> ['Age=Child']
# Support: 0.002271694684234439
# Confidence: 0.08064516129032258
# Lift: 1.6284403669724772
# ======================================
#
# Rule: ['Age=Child', 'Sex=Female', 'Class=2nd'] -> ['Survived=Yes']
# Support: 0.005906406179009541
# Confidence: 1.0
# Lift: 3.09563994374121
# ======================================
#
# Rule: ['Age=Child', 'Class=2nd', 'Survived=Yes'] -> ['Sex=Female']
# Support: 0.005906406179009541
# Confidence: 0.5416666666666666
# Lift: 2.536613475177305
# ======================================
#
# Rule: ['Age=Child', 'Sex=Female', 'Survived=Yes'] -> ['Class=2nd']
# Support: 0.005906406179009541
# Confidence: 0.4642857142857143
# Lift: 3.5855889724310774
# ======================================
#
# Rule: ['Sex=Female', 'Class=2nd', 'Survived=Yes'] -> ['Age=Child']
# Support: 0.005906406179009541
# Confidence: 0.13978494623655913
# Lift: 2.8226299694189603
# ======================================
#
# Rule: ['Age=Child', 'Sex=Male', 'Class=2nd'] -> ['Survived=Yes']
# Support: 0.004997728305315766
# Confidence: 1.0
# Lift: 3.09563994374121
# ======================================
#
# Rule: ['Age=Child', 'Sex=Male', 'Survived=Yes'] -> ['Class=2nd']
# Support: 0.004997728305315766
# Confidence: 0.3793103448275862
# Lift: 2.9293405928614638
# ======================================
#
# Rule: ['Sex=Male', 'Class=2nd', 'Survived=Yes'] -> ['Age=Child']
# Support: 0.004997728305315766
# Confidence: 0.44
# Lift: 8.884770642201834
# ======================================
#
# Rule: ['Age=Child', 'Survived=No', 'Class=3rd'] -> ['Sex=Female']
# Support: 0.007723761926397092
# Confidence: 0.3269230769230769
# Lift: 1.5309738134206219
# ======================================
#
# Rule: ['Age=Child', 'Survived=No', 'Sex=Female'] -> ['Class=3rd']
# Support: 0.007723761926397092
# Confidence: 1.0
# Lift: 3.1175637393767706
# ======================================
#
# Rule: ['Class=3rd', 'Survived=No', 'Sex=Female'] -> ['Age=Child']
# Support: 0.007723761926397092
# Confidence: 0.16037735849056603
# Lift: 3.238445559979228
# ======================================
#
# Rule: ['Age=Child', 'Sex=Female', 'Class=3rd'] -> ['Survived=Yes']
# Support: 0.006360745115856429
# Confidence: 0.45161290322580644
# Lift: 1.39803094233474
# ======================================
#
# Rule: ['Age=Child', 'Survived=Yes', 'Class=3rd'] -> ['Sex=Female']
# Support: 0.006360745115856429
# Confidence: 0.5185185185185185
# Lift: 2.4282111899133176
# ======================================
#
# Rule: ['Age=Child', 'Sex=Female', 'Survived=Yes'] -> ['Class=3rd']
# Support: 0.006360745115856429
# Confidence: 0.5
# Lift: 1.5587818696883853
# ======================================
#
# Rule: ['Class=3rd', 'Sex=Female', 'Survived=Yes'] -> ['Age=Child']
# Support: 0.006360745115856429
# Confidence: 0.15555555555555556
# Lift: 3.141080530071356
# ======================================
#
# Rule: ['Age=Child', 'Sex=Male', 'Survived=No'] -> ['Class=3rd']
# Support: 0.01590186278964107
# Confidence: 1.0
# Lift: 3.1175637393767706
# ======================================
#
# Rule: ['Class=3rd', 'Sex=Male', 'Survived=No'] -> ['Age=Child']
# Support: 0.01590186278964107
# Confidence: 0.0829383886255924
# Lift: 1.6747467281186135
# ======================================
#
# Rule: ['Age=Child', 'Sex=Male', 'Survived=Yes'] -> ['Class=3rd']
# Support: 0.005906406179009541
# Confidence: 0.44827586206896547
# Lift: 1.3975285728240694
# ======================================
#
# Rule: ['Class=3rd', 'Sex=Male', 'Survived=Yes'] -> ['Age=Child']
# Support: 0.005906406179009541
# Confidence: 0.14772727272727273
# Lift: 2.983006672226856
# ======================================

# %% [markdown]
# ### Prune rules by consequents

# %%
def prune_consequence(aprioriRules, support_minval, confidence_minval, consequence):
    for item in aprioriRules:
        for ruleNum in range(0,len(item[2])):
            a = item[2][ruleNum][0]
            b = item[2][ruleNum][1]
            support = str(item[1])
            confidence = str(item[2][ruleNum][2])
            lift = str(item[2][ruleNum][3])
            if consequence in str(list(b)) and float(support) > support_minval and float(confidence) > confidence_minval:
                
                outputString = '''Rule: {} -> {}
Support: {}
Confidence: {}
Lift: {}
======================================\n'''.format(str(list(a)),str(list(b)),support,\
                                             confidence ,lift)
                yield(outputString)

# %% [markdown]
# #### Print rules pruned by consequence

# %%
for val in prune_consequence(associationRules, 0.0045, 0.002, "Sex"):
    print(val)
# Out:
# Rule: ['Age=Child'] -> ['Sex=Female']
# Support: 0.02044525215810995
# Confidence: 0.41284403669724773
# Lift: 1.9333398399375368
# ======================================
#
# Rule: ['Class=1st'] -> ['Sex=Female']
# Support: 0.06587914584279873
# Confidence: 0.4461538461538462
# Lift: 2.089328968903437
# ======================================
#
# Rule: ['Class=2nd'] -> ['Sex=Female']
# Support: 0.0481599273057701
# Confidence: 0.37192982456140344
# Lift: 1.7417394550205298
# ======================================
#
# Rule: ['Class=3rd'] -> ['Sex=Female']
# Support: 0.08905043162199
# Confidence: 0.2776203966005666
# Lift: 1.3000904104635045
# ======================================
#
# Rule: ['Class=Crew'] -> ['Sex=Male']
# Support: 0.39164016356201725
# Confidence: 0.9740112994350282
# Lift: 1.2384742172481207
# ======================================
#
# Rule: ['Survived=Yes'] -> ['Sex=Female']
# Support: 0.1562925942753294
# Confidence: 0.48382559774964845
# Lift: 2.2657449800999494
# ======================================
#
# Rule: ['Survived=No'] -> ['Sex=Male']
# Support: 0.6197183098591549
# Confidence: 0.9154362416107382
# Lift: 1.163994897622897
# ======================================
#
# Rule: ['Class=1st', 'Age=Adult'] -> ['Sex=Female']
# Support: 0.06542480690595184
# Confidence: 0.4514106583072101
# Lift: 2.1139465083705735
# ======================================
#
# Rule: ['Class=2nd', 'Age=Adult'] -> ['Sex=Female']
# Support: 0.04225352112676056
# Confidence: 0.3563218390804598
# Lift: 1.668647591098068
# ======================================
#
# Rule: ['Class=3rd', 'Age=Adult'] -> ['Sex=Female']
# Support: 0.07496592457973648
# Confidence: 0.2631578947368421
# Lift: 1.2323628219484881
# ======================================
#
# Rule: ['Age=Adult', 'Class=Crew'] -> ['Sex=Male']
# Support: 0.39164016356201725
# Confidence: 0.9740112994350282
# Lift: 1.2384742172481207
# ======================================
#
# Rule: ['Age=Adult', 'Survived=Yes'] -> ['Sex=Female']
# Support: 0.14357110404361653
# Confidence: 0.4831804281345565
# Lift: 2.2627236645194873
# ======================================
#
# Rule: ['Survived=No', 'Age=Adult'] -> ['Sex=Male']
# Support: 0.6038164470695139
# Confidence: 0.9242002781641169
# Lift: 1.1751385397106997
# ======================================
#
# Rule: ['Age=Child', 'Class=2nd'] -> ['Sex=Female']
# Support: 0.005906406179009541
# Confidence: 0.5416666666666666
# Lift: 2.536613475177305
# ======================================
#
# Rule: ['Age=Child', 'Class=3rd'] -> ['Sex=Female']
# Support: 0.014084507042253521
# Confidence: 0.3924050632911393
# Lift: 1.8376245623485055
# ======================================
#
# Rule: ['Age=Child', 'Survived=No'] -> ['Sex=Female']
# Support: 0.007723761926397092
# Confidence: 0.3269230769230769
# Lift: 1.5309738134206219
# ======================================
#
# Rule: ['Age=Child', 'Survived=Yes'] -> ['Sex=Female']
# Support: 0.012721490231712857
# Confidence: 0.4912280701754386
# Lift: 2.3004106009705114
# ======================================
#
# Rule: ['Class=1st', 'Survived=Yes'] -> ['Sex=Female']
# Support: 0.06406179009541117
# Confidence: 0.6945812807881773
# Lift: 3.252709359605911
# ======================================
#
# Rule: ['Survived=No', 'Class=1st'] -> ['Sex=Male']
# Support: 0.05361199454793276
# Confidence: 0.9672131147540983
# Lift: 1.2298301938612193
# ======================================
#
# Rule: ['Class=2nd', 'Survived=Yes'] -> ['Sex=Female']
# Support: 0.04225352112676056
# Confidence: 0.788135593220339
# Lift: 3.690822214208439
# ======================================
#
# Rule: ['Survived=No', 'Class=2nd'] -> ['Sex=Male']
# Support: 0.06996819627442072
# Confidence: 0.9221556886227544
# Lift: 1.1725388045399667
# ======================================
#
# Rule: ['Class=3rd', 'Survived=Yes'] -> ['Sex=Female']
# Support: 0.0408905043162199
# Confidence: 0.5056179775280898
# Lift: 2.3677982309347354
# ======================================
#
# Rule: ['Survived=No', 'Class=Crew'] -> ['Sex=Male']
# Support: 0.3044070876874148
# Confidence: 0.9955423476968795
# Lift: 1.2658513618029068
# ======================================
#
# Rule: ['Class=Crew', 'Survived=Yes'] -> ['Sex=Male']
# Support: 0.08723307587460245
# Confidence: 0.9056603773584906
# Lift: 1.1515646970341062
# ======================================
#
# Rule: ['Class=1st', 'Age=Adult', 'Survived=Yes'] -> ['Sex=Female']
# Support: 0.06360745115856428
# Confidence: 0.7106598984771573
# Lift: 3.3280051841451557
# ======================================
#
# Rule: ['Survived=No', 'Class=1st', 'Age=Adult'] -> ['Sex=Male']
# Support: 0.05361199454793276
# Confidence: 0.9672131147540983
# Lift: 1.2298301938612193
# ======================================
#
# Rule: ['Class=2nd', 'Age=Adult', 'Survived=Yes'] -> ['Sex=Female']
# Support: 0.03634711494775102
# Confidence: 0.851063829787234
# Lift: 3.9855138071525578
# ======================================
#
# Rule: ['Survived=No', 'Class=2nd', 'Age=Adult'] -> ['Sex=Male']
# Support: 0.06996819627442072
# Confidence: 0.9221556886227544
# Lift: 1.1725388045399667
# ======================================
#
# Rule: ['Class=3rd', 'Age=Adult', 'Survived=Yes'] -> ['Sex=Female']
# Support: 0.03452975920036347
# Confidence: 0.5033112582781457
# Lift: 2.3569959137663803
# ======================================
#
# Rule: ['Survived=No', 'Age=Adult', 'Class=Crew'] -> ['Sex=Male']
# Support: 0.3044070876874148
# Confidence: 0.9955423476968795
# Lift: 1.2658513618029068
# ======================================
#
# Rule: ['Age=Adult', 'Survived=Yes', 'Class=Crew'] -> ['Sex=Male']
# Support: 0.08723307587460245
# Confidence: 0.9056603773584906
# Lift: 1.1515646970341062
# ======================================
#
# Rule: ['Age=Child', 'Class=2nd', 'Survived=Yes'] -> ['Sex=Female']
# Support: 0.005906406179009541
# Confidence: 0.5416666666666666
# Lift: 2.536613475177305
# ======================================
#
# Rule: ['Age=Child', 'Survived=No', 'Class=3rd'] -> ['Sex=Female']
# Support: 0.007723761926397092
# Confidence: 0.3269230769230769
# Lift: 1.5309738134206219
# ======================================
#
# Rule: ['Age=Child', 'Survived=Yes', 'Class=3rd'] -> ['Sex=Female']
# Support: 0.006360745115856429
# Confidence: 0.5185185185185185
# Lift: 2.4282111899133176
# ======================================

# %% [markdown]
# ### Prune redundant rules

# %%
def prune_redundant(aprioriRules, support_minval, confidence_minval):
    ruleList = []
    for item in aprioriRules:
        for ruleNum in range(0,len(item[2])):
            a = item[2][ruleNum][0]
            b = item[2][ruleNum][1]
            support = str(item[1])
            confidence = str(item[2][ruleNum][2])
            lift = str(item[2][ruleNum][3])
            if float(support) > support_minval and float(confidence) > confidence_minval:
                if str(list(b)) not in ruleList:
                    ruleList.append("{}".format(str(list(b))))
                                 
                    outputString = '''Rule: {} -> {}
Support: {}
Confidence: {}
Lift: {}
======================================\n'''.format(str(list(a)),str(list(b)),support,\
                                             confidence ,lift)
                    yield(outputString)

# %% [markdown]
# #### Print rules pruned by redundant consequences

# %%
for val in prune_redundant(associationRules, 0.0045, 0.2):
    print(val)
# Out:
# Rule: ['Age=Child'] -> ['Class=2nd']
# Support: 0.010904134484325307
# Confidence: 0.22018348623853212
# Lift: 1.7004345726702075
# ======================================
#
# Rule: ['Age=Child'] -> ['Class=3rd']
# Support: 0.03589277601090413
# Confidence: 0.7247706422018348
# Lift: 2.2595186734932557
# ======================================
#
# Rule: ['Age=Child'] -> ['Sex=Female']
# Support: 0.02044525215810995
# Confidence: 0.41284403669724773
# Lift: 1.9333398399375368
# ======================================
#
# Rule: ['Age=Child'] -> ['Survived=Yes']
# Support: 0.025897319400272602
# Confidence: 0.5229357798165137
# Lift: 1.6188208880114583
# ======================================
#
# Rule: ['Sex=Female'] -> ['Class=1st']
# Support: 0.06587914584279873
# Confidence: 0.3085106382978724
# Lift: 2.089328968903437
# ======================================
#
# Rule: ['Class=3rd'] -> ['Survived=No']
# Support: 0.23989095865515675
# Confidence: 0.7478753541076488
# Lift: 1.104747419054319
# ======================================
#
# Rule: ['Class=Crew'] -> ['Sex=Male']
# Support: 0.39164016356201725
# Confidence: 0.9740112994350282
# Lift: 1.2384742172481207
# ======================================
#
# Rule: ['Sex=Male'] -> ['Class=Crew']
# Support: 0.39164016356201725
# Confidence: 0.49797804737146156
# Lift: 1.2384742172481207
# ======================================
#
# Rule: ['Class=2nd', 'Survived=Yes'] -> ['Age=Child']
# Support: 0.010904134484325307
# Confidence: 0.2033898305084746
# Lift: 4.10698180687296
# ======================================
